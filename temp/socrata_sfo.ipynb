# %%
from dartfx.postman import socrata
from dartfx.postman import postman
import os
import logging
logging.basicConfig(level=logging.DEBUG)

# %%
# POSTMAN
postman_api = postman.PostmanApi(os.getenv("POSTMAN_API_KEY"))
dev_workspace_id = os.getenv("POSTMAN_WS_HVDN_DEV")
servers = {
    "sfo": {
        "host": "data.sfgov.org",
        "workspace_id": "77ed70b5-45eb-415d-8399-5b57fb74e960",
        "datasets": {
            "g8m3-pdis": "Registered Business Locations - San Francisco",
            "vw6y-z8j6": "311 Cases",
            "yitu-d5am": "Film Locations",
            "wg3w-h783": "Police Department Incident Reports: 2018 to Present",
            "tmnf-yvry": "Police Department Incident Reports: Historical 2003 to May 2018",
            "wr8u-xric": "Fire Incidents",
            "w4sk-nq57": "HSH Shelter Waitlist",
            "nuek-vuh3": "Fire Department and Emergency Medical Services Dispatched Calls for Service",
            "6d9h-4u5v": "Street Names",
            "rkru-6vcg": "Air Traffic Passenger Statistics"
        },
    }
}

# %%
# SOCRATA 
server_id = 'sfo'
server = socrata.SocrataServer(servers[server_id]['host'], disk_cache_root="../cache")

config = socrata.PostmanPublisherConfig()
config.name_prefix = "🔢 "

# %%
workspace_id = servers[server_id]['workspace_id']
workspace = postman.WorkspaceManager(postman_api, workspace_id)
for dataset_id in servers[server_id]['datasets'].keys():
    if dataset_id != 'vw6y-z8j6':
        #continue
        pass
    dataset = socrata.SocrataDataset(server, dataset_id)
    generator = socrata.PostmanCollectionGenerator(dataset, config=config)
    collection = generator.generate()
    collection.save('socrata_sfo.json')
    workspace.import_collection(collection.asdict(), replace=True)
# Out:
# DEBUG:root:Loading from disk cache ../cache/data.sfgov.org/g8m3-pdis.json
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): api.getpostman.com:443
# DEBUG:urllib3.connectionpool:https://api.getpostman.com:443 "GET /workspaces/77ed70b5-45eb-415d-8399-5b57fb74e960 HTTP/11" 200 1923
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): api.getpostman.com:443
# {'id': '4b3b304f-2b5d-480d-8978-ebd35ba694e2', 'name': '🔢 Street Names [6d9h-4u5v]', 'uid': '21577788-4b3b304f-2b5d-480d-8978-ebd35ba694e2'}
# {'id': 'be731496-393c-439f-8c67-77d9d683961c', 'name': '🔢 Fire Incidents [wr8u-xric]', 'uid': '21577788-be731496-393c-439f-8c67-77d9d683961c'}
# {'id': 'e33c258e-b04b-4ff3-ab90-021e93a24bd0', 'name': '🔢 Police Department Incident Reports: 2018 to Present [wg3w-h783]', 'uid': '21577788-e33c258e-b04b-4ff3-ab90-021e93a24bd0'}
# {'id': 'd2966220-0c58-4776-847e-aa1cc4e6a34d', 'name': '🔢 HSH Shelter Waitlist [w4sk-nq57]', 'uid': '21577788-d2966220-0c58-4776-847e-aa1cc4e6a34d'}
# {'id': 'bc1e7500-f406-468d-bbda-958a6783c8b7', 'name': '🔢 311 Cases [vw6y-z8j6]', 'uid': '21577788-bc1e7500-f406-468d-bbda-958a6783c8b7'}
# {'id': '4414a8c1-6981-44e7-8352-2fdea389fda6', 'name': '🔢 Police Department Incident Reports: Historical 2003 to May 2018 [tmnf-yvry]', 'uid': '21577788-4414a8c1-6981-44e7-8352-2fdea389fda6'}
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): api.getpostman.com:443
# {'id': 'bc1e7500-f406-468d-bbda-958a6783c8b7', 'name': '🔢 311 Cases [vw6y-z8j6]', 'uid': '21577788-bc1e7500-f406-468d-bbda-958a6783c8b7'}
# {'id': 'e33c258e-b04b-4ff3-ab90-021e93a24bd0', 'name': '🔢 Police Department Incident Reports: 2018 to Present [wg3w-h783]', 'uid': '21577788-e33c258e-b04b-4ff3-ab90-021e93a24bd0'}
# {'id': '4414a8c1-6981-44e7-8352-2fdea389fda6', 'name': '🔢 Police Department Incident Reports: Historical 2003 to May 2018 [tmnf-yvry]', 'uid': '21577788-4414a8c1-6981-44e7-8352-2fdea389fda6'}
# {'id': '76d6f397-e5f9-4107-b254-0dcf813d743a', 'name': '🔢 Fire Department and Emergency Medical Services Dispatched Calls for Service [nuek-vuh3]', 'uid': '21577788-76d6f397-e5f9-4107-b254-0dcf813d743a'}
# {'id': '430ea1fa-0755-4241-8e38-21787f75e5fe', 'name': '🔢 Air Traffic Passenger Statistics [rkru-6vcg]', 'uid': '21577788-430ea1fa-0755-4241-8e38-21787f75e5fe'}
# {'id': '4b3b304f-2b5d-480d-8978-ebd35ba694e2', 'name': '🔢 Street Names [6d9h-4u5v]', 'uid': '21577788-4b3b304f-2b5d-480d-8978-ebd35ba694e2'}
# DEBUG:urllib3.connectionpool:https://api.getpostman.com:443 "PUT /collections/4b3b304f-2b5d-480d-8978-ebd35ba694e2 HTTP/11" 200 144
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): api.getpostman.com:443
# DEBUG:urllib3.connectionpool:https://api.getpostman.com:443 "GET /workspaces/77ed70b5-45eb-415d-8399-5b57fb74e960 HTTP/11" 200 1923
# DEBUG:root:Loading from disk cache ../cache/data.sfgov.org/rkru-6vcg.json
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): api.getpostman.com:443
# {'id': 'be731496-393c-439f-8c67-77d9d683961c', 'name': '🔢 Fire Incidents [wr8u-xric]', 'uid': '21577788-be731496-393c-439f-8c67-77d9d683961c'}
# {'id': '4414a8c1-6981-44e7-8352-2fdea389fda6', 'name': '🔢 Police Department Incident Reports: Historical 2003 to May 2018 [tmnf-yvry]', 'uid': '21577788-4414a8c1-6981-44e7-8352-2fdea389fda6'}
# {'id': 'e33c258e-b04b-4ff3-ab90-021e93a24bd0', 'name': '🔢 Police Department Incident Reports: 2018 to Present [wg3w-h783]', 'uid': '21577788-e33c258e-b04b-4ff3-ab90-021e93a24bd0'}
# {'id': '07c0369f-1e84-4bd7-86eb-a34376abd607', 'name': '🔢 Registered Business Locations - San Francisco [g8m3-pdis]', 'uid': '21577788-07c0369f-1e84-4bd7-86eb-a34376abd607'}
# {'id': 'd2966220-0c58-4776-847e-aa1cc4e6a34d', 'name': '🔢 HSH Shelter Waitlist [w4sk-nq57]', 'uid': '21577788-d2966220-0c58-4776-847e-aa1cc4e6a34d'}
# {'id': '430ea1fa-0755-4241-8e38-21787f75e5fe', 'name': '🔢 Air Traffic Passenger Statistics [rkru-6vcg]', 'uid': '21577788-430ea1fa-0755-4241-8e38-21787f75e5fe'}
# DEBUG:urllib3.connectionpool:https://api.getpostman.com:443 "PUT /collections/430ea1fa-0755-4241-8e38-21787f75e5fe HTTP/11" 200 164
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): api.getpostman.com:443
# DEBUG:urllib3.connectionpool:https://api.getpostman.com:443 "GET /workspaces/77ed70b5-45eb-415d-8399-5b57fb74e960 HTTP/11" 200 1923
